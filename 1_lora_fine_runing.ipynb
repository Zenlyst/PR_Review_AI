# %% [markdown]
# # PR Review AI — LoRA Fine-Tuning
#
# Run these cells in order on a Colab Pro runtime (T4 or A100).

# %% [markdown]
# ## 1. Clone Repo
#
# **Prerequisite:** Push your local code to GitHub first:
# ```bash
# git add -A && git commit -m "add training pipeline" && git push origin main
# ```

# %%
import os

REPO_URL = "https://github.com/Zenlyst/PR_Review_AI.git"
REPO_DIR = "/content/PR_Review_AI"

if os.path.isdir(REPO_DIR):
    # Pull latest changes if repo already cloned
    # !cd {REPO_DIR} && git pull
else:
    # !git clone {REPO_URL} {REPO_DIR}

os.chdir(REPO_DIR)
print(f"Working directory: {os.getcwd()}")

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## 1.5 Pull Latest Changes
#
# After pushing fixes locally, run this cell to pull them in — **no runtime restart needed** thanks to `%autoreload`.

# %%
# !cd /content/PR_Review_AI && git pull

# %% [markdown]
# ## 2. Setup Environment

# %%
from training.setup_colab import setup

gpu_info = setup()
# Out:
# ...
# ⚙️  PR Review AI — Colab Setup
# ...
#
# 📦 Installing dependencies...
#    ✅ Dependencies installed
# ⚠️  Not running on Colab — skipping Drive mount
#    (Paths will still be created but may not persist)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 3
#       1 from training.setup_colab import setup
# ----> 3 gpu_info = setup()
#
# File ~/Documents/_Personal/Projects/pr-review-ai/training/setup_colab.py:150, in setup()
#     148 install_dependencies()
#     149 mount_google_drive()
# --> 150 create_directories()
#     151 gpu_info = detect_gpu()
#     153 print("\n" + "=" * 60)
#
# File ~/Documents/_Personal/Projects/pr-review-ai/training/setup_colab.py:71, in create_directories()
#      68 dirs = [DRIVE_PROJECT_DIR, CHECKPOINT_DIR, LOGGING_DIR, ADAPTER_DIR, CACHED_DATASET_DIR]
#      70 for d in dirs:
# ---> 71     os.makedirs(d, exist_ok=True)
# ...

# %% [markdown]
# ## 3. Train

# %%
from training.train import run_training

trainer = run_training()

# %% [markdown]
# ## 4. Test Inference

# %%
from training.model import load_for_inference
from training.inference import run_test_examples

model, tokenizer = load_for_inference()
run_test_examples(model, tokenizer)

# %% [markdown]
# ## 5. Custom Review (optional)
#
# Try the model on your own code:

# %%
from training.inference import generate_review

review = generate_review(
    model=model,
    tokenizer=tokenizer,
    before_code="def add(a, b):\n    return a + b",
    after_code="def add(a, b):\n    return a - b",
    file_path="math_utils.py",
)
print(review)
